# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# ppi_df  = pd.read_csv('ppi.csv')



# ppi_df.dropna(inplace=True)
# ppi_df0 = ppi_df[ppi_df['ppi5'] == 0]
# ppi_df0_avg = ppi_df0[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df0_std = ppi_df0[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df0_avg.head())
# # print(ppi_df0_std.head())


# ppi_df1 = ppi_df[ppi_df['ppi5'] == 1]
# ppi_df1_avg = ppi_df1[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df1_std = ppi_df1[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df1_avg.head())
# # print(ppi_df1_std.head())


# ppi_df2 = ppi_df[ppi_df['ppi5'] == 2]
# ppi_df2_avg = ppi_df2[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df2_std = ppi_df2[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df2_avg.head())
# # print(ppi_df2_std.head())

# ppi_df3 = ppi_df[ppi_df['ppi5'] == 3]
# ppi_df3_avg = ppi_df3[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df3_std = ppi_df3[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df3_avg.head())
# # print(ppi_df3_std.head())

# ppi_df4 = ppi_df[ppi_df['ppi5'] == 4]
# ppi_df4_avg = ppi_df4[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df4_std = ppi_df4[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df4_avg.head())
# # print(ppi_df4_std.head())

# ppi_df5 = ppi_df[ppi_df['ppi5'] == 5]
# ppi_df5_avg = ppi_df5[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].mean()
# ppi_df5_std = ppi_df5[['nhwhi_10', 'nhaa_10', 'nhapi_10', 'lat_10', 'nhoth_10']].std()
# # print(ppi_df5_avg.head())
# # print(ppi_df5_std.head())

#print(census0[0 : 10])

# %%
ppi_values = [0, 1, 2, 3, 4, 5]  # List of PPI values
for ppi_value in ppi_values:
    # Get the mean and standard deviation values for a specific PPI value
    ppi_df_avg = ppi_df[ppi_df['ppi5'] == ppi_value][['nhwhi_10', 'nhaa_10', 'nhapi_10', 'nhoth_10', 'lat_10']].mean()
    ppi_df_std = ppi_df[ppi_df['ppi5'] == ppi_value][['nhwhi_10', 'nhaa_10', 'nhapi_10', 'nhoth_10', 'lat_10']].std()

    # Create a separate plot for each PPI value
    plt.figure(figsize=(8, 6))

    # Plot the means
    plt.bar(ppi_df_avg.index, ppi_df_avg, yerr=ppi_df_std, capsize=5, align='center', alpha=0.7, ecolor='black', label='Population Density')

    plt.xlabel('Racial Categories')
    plt.ylabel('Population Density')
    plt.title(f'Population Density Mean and Standard Deviation for PPI {ppi_value}')
    plt.xticks(range(len(ppi_df_avg.index)), ppi_df_avg.index)  # Assuming ppi_df_avg.index contains race names
    plt.legend()
    plt.tight_layout()

# %%
ppi_values = [0, 1, 2, 3, 4, 5]  # List of PPI values
for ppi_value in ppi_values:
    # Get the mean and standard deviation values for a specific PPI value
    ppi_df = ppi_df[ppi_df['ppi5'] == ppi_value][['commtypeid']]    
    #print(ppi_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-3c734e208f0e> in <module>
#       2 for ppi_value in ppi_values:
#       3     # Get the mean and standard deviation values for a specific PPI value
# ----> 4     ppi_df = ppi_df[ppi_df['ppi5'] == ppi_value][['commtypeid']]
#       5     print(ppi_df)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['commtypeid'], dtype='object')] are in the [columns]"
